# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pandas
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
df = pandas.read_csv('Data/EcommerceCustomers.csv')
# Drop non-numeric columns
df = df.drop(columns=["Email", "Address", "Avatar"])

# Convert to NumPy
data = df.to_numpy()

# Split into features (X) and target (y)
X, y = data[:, :-1], data[:, -1]

# Check the shapes
print("X shape:", X.shape)  # (n_samples, n_features)
print("y shape:", y.shape)  # (n_samples,)
X_train
# Out:
# X shape: (500, 4)
# y shape: (500,)
# array([[31.52575242, 11.34003593, 37.03951365,  3.81124817],
#        [31.86274111, 14.03986726, 37.02226899,  3.73822517],
#        [33.25823783, 11.51494907, 37.1280395 ,  4.6628453 ],
#        ...,
#        [31.82797906, 12.46114744, 37.42899737,  2.97473682],
#        [33.87936082, 11.584783  , 37.08792607,  3.7132092 ],
#        [32.18984473, 11.38677555, 38.19748325,  4.80832037]])

# %% [markdown]
# # Split Training data

# %%
X,y  = datasets.make_regression(n_samples=100, n_features=1, noise=10, random_state=42)
#Split training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Call myLinearRegression

# %%
import importlib
import MyLinearRegression
importlib.reload(MyLinearRegression)
from MyLinearRegression import MyLinearRegression

# %%
lm = MyLinearRegression()

# %%
lm.fit(X_train, y_train)

# %%
predictions = lm.prediction(X_test)

# %%
sns.scatterplot(x=predictions, y=y_test)
plt.xlabel('Predicted Y')
plt.title('Predicted vs Actual Y')
# Out:
# Text(0.5, 1.0, 'Predicted vs Actual Y')

# %% [markdown]
# # Analysis

# %%
rmse_value = lm.rmse(X_test, y_test)
print(rmse_value)
# Out:
# 15.45049578998118

# %%
residuals = y_test - predictions
sns.displot(residuals, bins=20, kde=True)
